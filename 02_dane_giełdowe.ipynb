# %% [markdown]
# <a href="https://colab.research.google.com/github/KrzysztofNa/data_science_bootcamp/blob/master/02_dane_gie%C5%82dowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
def fetch_financial_data(company='AMZN'):
  # pobieranie danych giełdowych ze strony stooq.pl
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2020-08-21 to 2015-08-26
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df.head()
# Out:
#                open       high        low    close   volume
# Date
# 2020-08-21  3295.00  3314.3962  3275.3900  3284.72  3575862
# 2020-08-20  3252.00  3312.6200  3238.0000  3297.37  3332478
# 2020-08-19  3303.01  3315.9000  3256.0001  3260.48  4185137
# 2020-08-18  3212.00  3320.0000  3205.8187  3312.49  5345974
# 2020-08-17  3173.12  3194.9700  3154.1775  3182.41  2691237

# %%
df.columns = [col.lower() for col in df.columns]
df.head()
# Out:
#                open       high        low    close   volume
# Date
# 2020-08-21  3295.00  3314.3962  3275.3900  3284.72  3575862
# 2020-08-20  3252.00  3312.6200  3238.0000  3297.37  3332478
# 2020-08-19  3303.01  3315.9000  3256.0001  3260.48  4185137
# 2020-08-18  3212.00  3320.0000  3205.8187  3312.49  5345974
# 2020-08-17  3173.12  3194.9700  3154.1775  3182.41  2691237

# %%
df.describe().T
# Out:
#          count          mean  ...          75%          max
# open    1259.0  1.369037e+03  ...     1811.850      3303.01
# high    1259.0  1.383081e+03  ...     1829.080      3344.29
# low     1259.0  1.353458e+03  ...     1797.745      3275.39
# close   1259.0  1.369165e+03  ...     1813.365      3312.49
# volume  1259.0  4.270129e+06  ...  5114193.000  16552598.00
#
# [5 rows x 8 columns]

# %%
df['open']
# Out:
# Date
# 2020-08-21    3295.00
# 2020-08-20    3252.00
# 2020-08-19    3303.01
# 2020-08-18    3212.00
# 2020-08-17    3173.12
#                ...
# 2015-08-28     517.50
# 2015-08-27     513.71
# 2015-08-26     484.02
# 2015-08-25     487.49
# 2015-08-24     463.58
# Name: open, Length: 1259, dtype: float64

# %%
df.iloc[:,[1,2]].head()
# Out:
#                  high        low
# Date
# 2020-08-21  3314.3962  3275.3900
# 2020-08-20  3312.6200  3238.0000
# 2020-08-19  3315.9000  3256.0001
# 2020-08-18  3320.0000  3205.8187
# 2020-08-17  3194.9700  3154.1775

# %%
df.iloc[:,[-1]].head()
# Out:
#              volume
# Date
# 2020-08-21  3575862
# 2020-08-20  3332478
# 2020-08-19  4185137
# 2020-08-18  5345974
# 2020-08-17  2691237

# %%
df.loc['2020-08-20':'2020-08-17']
# Out:
#                open     high        low    close   volume
# Date
# 2020-08-20  3252.00  3312.62  3238.0000  3297.37  3332478
# 2020-08-19  3303.01  3315.90  3256.0001  3260.48  4185137
# 2020-08-18  3212.00  3320.00  3205.8187  3312.49  5345974
# 2020-08-17  3173.12  3194.97  3154.1775  3182.41  2691237

# %%
df=fetch_financial_data('UBER')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 325 entries, 2020-08-21 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    325 non-null    float64
#  1   High    325 non-null    float64
#  2   Low     325 non-null    float64
#  3   Close   325 non-null    float64
#  4   Volume  325 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 15.2 KB

# %%
df['Average'] = (df.Open + df.Close)/2
df.head()
# Out:
#              Open    High      Low  Close    Volume  Average
# Date
# 2020-08-21  31.39  31.820  30.7144  30.83  20216997   31.110
# 2020-08-20  29.13  31.700  28.4800  31.41  56663347   30.270
# 2020-08-19  30.15  30.349  29.3900  29.42  14050333   29.785
# 2020-08-18  29.50  30.460  29.4100  30.08  29398212   29.790
# 2020-08-17  30.05  30.120  29.1400  29.48  18544676   29.765

# %%
df = df.sort_index()
df.head()
# Out:
#              Open   High    Low  Close     Volume  Average
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240

# %%
df['Close_shift'] = df.Close.shift(1)
df.head()
# Out:
#              Open   High    Low  Close     Volume  Average  Close_shift
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945        41.57
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135        37.10
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240        41.29

# %%
df['Daily_Change'] = df.Close / df.Close_shift - 1
df.head()
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN           NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57     -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96      0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29      0.041414
#
# [5 rows x 8 columns]

# %%
df.Daily_Change.min()
# Out:
# -0.21628767847699626

# %%
df.Daily_Change.max()
# Out:
# 0.3825910931174088

# %%
df.Daily_Change.hist(bins=100)

# %%
df.Close.plot()

# %%
df_positive = df[df.Daily_Change > 0]
df_positive.head()
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96      0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29      0.041414
# 2019-05-24  41.28  41.51  40.50  ...   41.395        40.47      0.025698
# 2019-05-31  41.15  41.57  39.41  ...   40.780        39.80      0.015327
#
# [5 rows x 8 columns]

# %%
df[df.index.year == 2019]
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_Change
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN           NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57     -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10      0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96      0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29      0.041414
# ...           ...    ...    ...  ...      ...          ...           ...
# 2019-12-24  30.33  30.84  30.11  ...   30.385        30.33      0.003627
# 2019-12-26  30.47  30.79  30.03  ...   30.570        30.44      0.007556
# 2019-12-27  30.80  31.06  30.17  ...   30.485        30.67     -0.016303
# 2019-12-30  30.13  30.20  29.35  ...   29.935        30.17     -0.014253
# 2019-12-31  29.11  29.95  28.90  ...   29.425        29.74      0.000000
#
# [163 rows x 8 columns]

# %%
df = fetch_financial_data('FB')
df.head()
# Out:
#                Open      High     Low   Close    Volume
# Date
# 2020-08-21  268.690  270.4900  266.42  267.01  15538615
# 2020-08-20  261.500  269.6300  261.46  269.01  20299688
# 2020-08-19  261.388  267.9080  261.35  262.59  23291463
# 2020-08-18  260.950  265.1500  259.26  262.34  18690383
# 2020-08-17  262.500  264.0973  259.40  261.16  13351062

# %%
df = pd.read_csv('london_bike.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-83f96cfe3bfe> in <module>()
# ----> 1 df = pd.read_csv('london_bike.csv')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File london_bike.csv does not exist: 'london_bike.csv'

# %%
apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2020-08-21 to 2015-08-26
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.head()
# Out:
#                Open     High       Low   Close    Volume
# Date
# 2020-08-21  477.050  499.472  477.0000  497.48  84513660
# 2020-08-20  463.000  473.568  462.9335  473.10  31726797
# 2020-08-19  463.933  468.650  462.4400  462.83  36384502
# 2020-08-18  457.410  464.000  456.0300  462.25  26408385
# 2020-08-17  464.250  464.350  455.8501  458.43  29890361

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis = 1)

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
df.describe().T
# Out:
#                      count        mean  ...         75%          max
# apple_apple_open   1257.00      175.64  ...      205.82       477.05
# apple_apple_high   1257.00      177.48  ...      207.31       499.47
# apple_apple_low    1257.00      174.02  ...      203.93       477.00
# apple_apple_close  1257.00      175.88  ...      205.60       497.48
# apple_apple_volume 1257.00 35163164.09  ... 41486205.00 141273049.00
# amazon_open        1257.00     1370.46  ...     1812.14      3303.01
# amazon_high        1257.00     1384.50  ...     1829.41      3344.29
# amazon_low         1257.00     1354.88  ...     1798.11      3275.39
# amazon_close       1257.00     1370.60  ...     1813.70      3312.49
# amazon_volume      1257.00  4264373.43  ...  5106920.00  16552598.00
# google_open        1257.00     1032.74  ...     1189.69      1585.03
# google_high        1257.00     1042.33  ...     1200.20      1591.88
# google_low         1257.00     1022.93  ...     1176.25      1562.31
# google_close       1257.00     1033.15  ...     1190.13      1576.25
# google_volume      1257.00  1770207.39  ...  2037263.00   6658855.00
# uber_open           325.00       33.80  ...       37.53        46.98
# uber_high           325.00       34.48  ...       37.94        47.08
# uber_low            325.00       32.98  ...       36.73        45.08
# uber_close          325.00       33.75  ...       37.08        46.38
# uber_volume         325.00 25155181.36  ... 33144371.00 186322536.00
#
# [20 rows x 8 columns]

# %%
df.corr()
# Out:
#                     apple_apple_open  apple_apple_high  ...  uber_close  uber_volume
# apple_apple_open                1.00              1.00  ...       -0.33         0.16
# apple_apple_high                1.00              1.00  ...       -0.34         0.17
# apple_apple_low                 1.00              1.00  ...       -0.32         0.15
# apple_apple_close               1.00              1.00  ...       -0.33         0.16
# apple_apple_volume             -0.05             -0.04  ...       -0.37         0.39
# amazon_open                     0.93              0.93  ...       -0.10        -0.00
# amazon_high                     0.93              0.93  ...       -0.11         0.01
# amazon_low                      0.93              0.93  ...       -0.09        -0.01
# amazon_close                    0.93              0.93  ...       -0.10         0.00
# amazon_volume                   0.12              0.13  ...       -0.26         0.29
# google_open                     0.93              0.93  ...       -0.19         0.12
# google_high                     0.93              0.93  ...       -0.21         0.14
# google_low                      0.93              0.93  ...       -0.16         0.09
# google_close                    0.93              0.93  ...       -0.19         0.12
# google_volume                   0.06              0.07  ...       -0.27         0.35
# uber_open                      -0.33             -0.34  ...        0.99        -0.32
# uber_high                      -0.34             -0.35  ...        0.99        -0.28
# uber_low                       -0.32             -0.33  ...        0.99        -0.34
# uber_close                     -0.33             -0.34  ...        1.00        -0.31
# uber_volume                     0.16              0.17  ...       -0.31         1.00
#
# [20 rows x 20 columns]

# %%
closes = [col for col in df.columns if col.endswith('close') or col.endswith('volume') ]
closes
# Out:
# ['apple_apple_close',
#  'apple_apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes].corr()
# Out:
#                     apple_apple_close  ...  uber_volume
# apple_apple_close                1.00  ...         0.16
# apple_apple_volume              -0.05  ...         0.39
# amazon_close                     0.93  ...         0.00
# amazon_volume                    0.12  ...         0.29
# google_close                     0.93  ...         0.12
# google_volume                    0.06  ...         0.35
# uber_close                      -0.33  ...        -0.31
# uber_volume                      0.16  ...         1.00
#
# [8 rows x 8 columns]
